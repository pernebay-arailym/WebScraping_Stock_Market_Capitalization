# %%
from bs4 import  BeautifulSoup
import requests

# %%
url = 'https://en.wikipedia.org/wiki/List_of_countries_by_stock_market_capitalization'
page = requests.get(url)
soup = BeautifulSoup(page.text, 'html')

# %%
print(soup)  # .prettify() This will print the HTML content in a readable format
# Out:
# <!DOCTYPE html>
# <html class="client-nojs vector-feature-language-in-header-enabled vector-feature-language-in-main-page-header-disabled vector-feature-page-tools-pinned-disabled vector-feature-toc-pinned-clientpref-1 vector-feature-main-menu-pinned-disabled vector-feature-limited-width-clientpref-1 vector-feature-limited-width-content-enabled vector-feature-custom-font-size-clientpref-1 vector-feature-appearance-pinned-clientpref-1 vector-feature-night-mode-enabled skin-theme-clientpref-day vector-sticky-header-enabled vector-toc-available" dir="ltr" lang="en">
# <head>
# <meta charset="utf-8"/>
# <title>List of countries by stock market capitalization - Wikipedia</title>
# ...

# %%
soup.find_all('table')[1]
# Out:
# <table class="wikitable sortable">
# <tbody><tr>
# <th rowspan="2">Year
# </th>
# <th colspan="2">World market cap
# </th>
# <th rowspan="2">Number of<br/>listed<br/>companies
# </th></tr>
# <tr>
# <th>Millions<br/>of US$
# </th>
# <th>% of <a href="/wiki/Gross_domestic_product" title="Gross domestic product">GDP</a>
# </th></tr>
# <tr>
# <td>1975
# </td>
# <td>1,149,245
# </td>
# <td>27.2
# </td>
# <td>14,577
# </td></tr>
# <tr>
# <td>1980
# </td>
# <td>2,525,736
# </td>
# <td>29.6
# </td>
# <td>17,273
# </td></tr>
# <tr>
# <td>1985
# </td>
# <td>4,684,978
# </td>
# <td>47.0
# </td>
# <td>20,555
# </td></tr>
# <tr>
# <td>1990
# </td>
# <td>9,519,107
# </td>
# <td>50.8
# </td>
# <td>23,732
# </td></tr>
# <tr>
# <td>1991
# </td>
# <td>11,340,785
# </td>
# <td>56.8
# </td>
# <td>24,666
# </td></tr>
# <tr>
# <td>1992
# </td>
# <td>10,819,256
# </td>
# <td>50.2
# </td>
# <td>24,947
# </td></tr>
# <tr>
# <td>1993
# </td>
# <td>13,897,390
# </td>
# <td>61.7
# </td>
# <td>28,300
# ...

# %%
soup.find('table', class_='wikitable sortable')
# Out:
# <table class="wikitable sortable">
# <tbody><tr>
# <th rowspan="2">Year
# </th>
# <th colspan="2">World market cap
# </th>
# <th rowspan="2">Number of<br/>listed<br/>companies
# </th></tr>
# <tr>
# <th>Millions<br/>of US$
# </th>
# <th>% of <a href="/wiki/Gross_domestic_product" title="Gross domestic product">GDP</a>
# </th></tr>
# <tr>
# <td>1975
# </td>
# <td>1,149,245
# </td>
# <td>27.2
# </td>
# <td>14,577
# </td></tr>
# <tr>
# <td>1980
# </td>
# <td>2,525,736
# </td>
# <td>29.6
# </td>
# <td>17,273
# </td></tr>
# <tr>
# <td>1985
# </td>
# <td>4,684,978
# </td>
# <td>47.0
# </td>
# <td>20,555
# </td></tr>
# <tr>
# <td>1990
# </td>
# <td>9,519,107
# </td>
# <td>50.8
# </td>
# <td>23,732
# </td></tr>
# <tr>
# <td>1991
# </td>
# <td>11,340,785
# </td>
# <td>56.8
# </td>
# <td>24,666
# </td></tr>
# <tr>
# <td>1992
# </td>
# <td>10,819,256
# </td>
# <td>50.2
# </td>
# <td>24,947
# </td></tr>
# <tr>
# <td>1993
# </td>
# <td>13,897,390
# </td>
# <td>61.7
# </td>
# <td>28,300
# ...

# %%
table =soup.find_all('table')[0]

# %%
# Get the two header rows
header_rows = table.find_all('tr')[:2]
first_row = header_rows[0].find_all('th')
second_row = header_rows[1].find_all('th')

world_table_titles=[]

for th in first_row:
    colspan = int(th.get('colspan', 1))
    if colspan == 2:
        sub1 = second_row[0].text.strip()
        sub2 = second_row[1].text.strip()
        world_table_titles.append(f"Total market cap ({sub1})")
        world_table_titles.append(f"Total market cap ({sub2})")
    else:
        world_table_titles.append(th.text.strip())

# %%
print(world_table_titles)
# Out:
# ['Country / Territory', 'Total market cap ((in millionsof US$)[4])', 'Total market cap ((as a\xa0%of GDP)[5])', 'Number ofdomesticcompanieslisted[3]', 'Year']

# %%
import pandas as pd

# %%
df = pd.DataFrame(columns =world_table_titles)
df
# Out:
# Empty DataFrame
# Columns: [Country / Territory, Total market cap ((in millionsof US$)[4]), Total market cap ((as a %of GDP)[5]), Number ofdomesticcompanieslisted[3], Year]
# Index: []
